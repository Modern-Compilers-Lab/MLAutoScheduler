# %%
# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np

species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/ericasare/Desktop/Desktop/Mac2023/School/Fall2023NewYork/Capstone/MLScheduler/perf.ipynb Cell 1 line <cell line: 29>()
#      <a href='vscode-notebook-cell:/Users/ericasare/Desktop/Desktop/Mac2023/School/Fall2023NewYork/Capstone/MLScheduler/perf.ipynb#W0sZmlsZQ%3D%3D?line=26'>27</a> ax.set_title('Penguin attributes by species')
#      <a href='vscode-notebook-cell:/Users/ericasare/Desktop/Desktop/Mac2023/School/Fall2023NewYork/Capstone/MLScheduler/perf.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a> ax.set_xticks(x + width, species)
# ---> <a href='vscode-notebook-cell:/Users/ericasare/Desktop/Desktop/Mac2023/School/Fall2023NewYork/Capstone/MLScheduler/perf.ipynb#W0sZmlsZQ%3D%3D?line=28'>29</a> ax.legend(loc='upper left', ncols=3)
#      <a href='vscode-notebook-cell:/Users/ericasare/Desktop/Desktop/Mac2023/School/Fall2023NewYork/Capstone/MLScheduler/perf.ipynb#W0sZmlsZQ%3D%3D?line=29'>30</a> ax.set_ylim(0, 250)
#      <a href='vscode-notebook-cell:/Users/ericasare/Desktop/Desktop/Mac2023/School/Fall2023NewYork/Capstone/MLScheduler/perf.ipynb#W0sZmlsZQ%3D%3D?line=31'>32</a> plt.show()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:305, in Axes.legend(self, *args, **kwargs)
#     303 if len(extra_args):
#     304     raise TypeError('legend only accepts two non-keyword arguments')
# --> 305 self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     306 self.legend_._remove_method = self._remove_legend
#     307 return self.legend_
#
# TypeError: __init__() got an unexpected keyword argument 'ncols'
